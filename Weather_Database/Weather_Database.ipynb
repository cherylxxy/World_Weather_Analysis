# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.0, 90.0, size=2000)
lngs = np.random.uniform(-180.0, 180.0, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 717

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        weather = {}
        weather['City'] = city
        weather['Country'] = city_weather['sys']['country']
        weather['Lat'] = city_weather['coord']['lat']
        weather['Lng'] = city_weather['coord']['lon']
        weather['Max Temp'] = city_weather['main']['temp_max']
        weather['Humidity'] = city_weather['main']['humidity']
        weather['Cloudiness'] = city_weather['clouds']['all']
        weather['Wind Speed'] = city_weather['wind']['speed']
        weather['Current Description'] = city_weather['weather'][0]['description']
        # Append the city information into the city_data list
        city_data.append(weather)
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | concepcion del oro
# Processing Record 4 of Set 1 | lagoa
# Processing Record 5 of Set 1 | nishihara
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 1 | mayumba
# Processing Record 9 of Set 1 | nadym
# Processing Record 10 of Set 1 | saint-pierre
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | tongliao
# Processing Record 13 of Set 1 | san cristobal
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | galveston
# Processing Record 16 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 17 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 18 of Set 1 | camopi
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | severo-kurilsk
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | rio tuba
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | prainha
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | bodden town
# Processing Record 29 of Set 1 | san carlos de bariloche
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | vanavara
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | geraldton
# Processing Record 37 of Set 1 | rabupura
# Processing Record 38 of Set 1 | ambilobe
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | kavieng
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | coquimbo
# Processing Record 43 of Set 1 | saint george
# Processing Record 44 of Set 1 | luderitz
# Processing Record 45 of Set 1 | port blair
# Processing Record 46 of Set 1 | lavrentiya
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | lompoc
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | shiringushi
# Processing Record 5 of Set 2 | valparaiso
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | antalaha
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | ekibastuz
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | taos
# Processing Record 15 of Set 2 | chiang rai
# Processing Record 16 of Set 2 | tuatapere
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | karratha
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | vanimo
# Processing Record 21 of Set 2 | margate
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | goure
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 2 | kloulklubed
# Processing Record 27 of Set 2 | wad rawah
# Processing Record 28 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 2 | elko
# Processing Record 30 of Set 2 | abu dhabi
# Processing Record 31 of Set 2 | faya
# Processing Record 32 of Set 2 | oshkosh
# Processing Record 33 of Set 2 | new norfolk
# Processing Record 34 of Set 2 | cachoeira do sul
# Processing Record 35 of Set 2 | sidi ali
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | sechura
# Processing Record 38 of Set 2 | santa fe
# Processing Record 39 of Set 2 | kupino
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | bury saint edmunds
# City not found. Skipping...
# Processing Record 43 of Set 2 | orlik
# Processing Record 44 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | mubi
# Processing Record 50 of Set 2 | rio gallegos
# Processing Record 1 of Set 3 | ponta delgada
# Processing Record 2 of Set 3 | scottsbluff
# Processing Record 3 of Set 3 | kapaa
# Processing Record 4 of Set 3 | huarmey
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | tricase
# Processing Record 7 of Set 3 | havoysund
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | padang
# Processing Record 10 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | bichura
# Processing Record 13 of Set 3 | vangaindrano
# Processing Record 14 of Set 3 | ucluelet
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | mareeba
# Processing Record 18 of Set 3 | placido de castro
# Processing Record 19 of Set 3 | honningsvag
# Processing Record 20 of Set 3 | kijang
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | kamaishi
# Processing Record 23 of Set 3 | segezha
# Processing Record 24 of Set 3 | santa cruz
# Processing Record 25 of Set 3 | hasaki
# Processing Record 26 of Set 3 | victoria
# Processing Record 27 of Set 3 | jesup
# Processing Record 28 of Set 3 | rocha
# Processing Record 29 of Set 3 | kushikino
# Processing Record 30 of Set 3 | beloha
# Processing Record 31 of Set 3 | voyvozh
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | lazaro cardenas
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | taltal
# Processing Record 37 of Set 3 | we
# City not found. Skipping...
# Processing Record 38 of Set 3 | mankera
# Processing Record 39 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 3 | koutsouras
# Processing Record 41 of Set 3 | sitka
# Processing Record 42 of Set 3 | ahipara
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | dhidhdhoo
# Processing Record 45 of Set 3 | hovd
# Processing Record 46 of Set 3 | urusha
# Processing Record 47 of Set 3 | narok
# Processing Record 48 of Set 3 | gigmoto
# Processing Record 49 of Set 3 | balakliya
# Processing Record 50 of Set 3 | entre rios
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | avarua
# Processing Record 3 of Set 4 | atambua
# Processing Record 4 of Set 4 | gubkinskiy
# Processing Record 5 of Set 4 | havelock
# Processing Record 6 of Set 4 | rosamorada
# Processing Record 7 of Set 4 | brunico
# Processing Record 8 of Set 4 | liverpool
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | havre-saint-pierre
# Processing Record 11 of Set 4 | ville-marie
# Processing Record 12 of Set 4 | lucapa
# Processing Record 13 of Set 4 | atuona
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | bonavista
# Processing Record 16 of Set 4 | sola
# Processing Record 17 of Set 4 | portland
# Processing Record 18 of Set 4 | buala
# Processing Record 19 of Set 4 | catuday
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | izumo
# Processing Record 22 of Set 4 | sao felix do xingu
# Processing Record 23 of Set 4 | de aar
# Processing Record 24 of Set 4 | umm kaddadah
# Processing Record 25 of Set 4 | vardo
# Processing Record 26 of Set 4 | bilibino
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | kandrian
# Processing Record 29 of Set 4 | nocupetaro
# Processing Record 30 of Set 4 | moron
# Processing Record 31 of Set 4 | aykhal
# Processing Record 32 of Set 4 | meulaboh
# Processing Record 33 of Set 4 | russell
# Processing Record 34 of Set 4 | touros
# Processing Record 35 of Set 4 | bathsheba
# Processing Record 36 of Set 4 | san andres
# Processing Record 37 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 4 | muli
# Processing Record 39 of Set 4 | baker city
# Processing Record 40 of Set 4 | pattoki
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | bossangoa
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | gizo
# Processing Record 47 of Set 4 | sao joao de pirabas
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | uglovskoye
# Processing Record 50 of Set 4 | seoul
# Processing Record 1 of Set 5 | amarante do maranhao
# Processing Record 2 of Set 5 | kaitangata
# Processing Record 3 of Set 5 | caledon
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | hithadhoo
# Processing Record 6 of Set 5 | salalah
# Processing Record 7 of Set 5 | kuandian
# Processing Record 8 of Set 5 | naze
# Processing Record 9 of Set 5 | mogadouro
# Processing Record 10 of Set 5 | tamworth
# Processing Record 11 of Set 5 | presidencia roque saenz pena
# Processing Record 12 of Set 5 | pacific grove
# Processing Record 13 of Set 5 | port hardy
# Processing Record 14 of Set 5 | pauini
# Processing Record 15 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 5 | berlevag
# Processing Record 17 of Set 5 | lloydminster
# Processing Record 18 of Set 5 | koyilandi
# City not found. Skipping...
# Processing Record 19 of Set 5 | ormara
# Processing Record 20 of Set 5 | arraial do cabo
# Processing Record 21 of Set 5 | mendeleyevskiy
# Processing Record 22 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 5 | deputatskiy
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | adrar
# Processing Record 26 of Set 5 | nouadhibou
# Processing Record 27 of Set 5 | potiskum
# Processing Record 28 of Set 5 | rawson
# Processing Record 29 of Set 5 | rindal
# Processing Record 30 of Set 5 | boa vista
# Processing Record 31 of Set 5 | codrington
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | chitral
# Processing Record 34 of Set 5 | marawi
# Processing Record 35 of Set 5 | mamallapuram
# Processing Record 36 of Set 5 | mount gambier
# Processing Record 37 of Set 5 | livingston
# Processing Record 38 of Set 5 | samarai
# Processing Record 39 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 40 of Set 5 | patacamaya
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | thinadhoo
# Processing Record 43 of Set 5 | pokhara
# Processing Record 44 of Set 5 | kirakira
# Processing Record 45 of Set 5 | batalha
# Processing Record 46 of Set 5 | troitsko-pechorsk
# Processing Record 47 of Set 5 | vestmannaeyjar
# Processing Record 48 of Set 5 | ostersund
# Processing Record 49 of Set 5 | nikolskoye
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | asau
# Processing Record 2 of Set 6 | sabang
# Processing Record 3 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 6 | basco
# Processing Record 5 of Set 6 | ullapool
# Processing Record 6 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | ugoofaaru
# Processing Record 9 of Set 6 | san quintin
# Processing Record 10 of Set 6 | emerald
# Processing Record 11 of Set 6 | zhigansk
# Processing Record 12 of Set 6 | imeni poliny osipenko
# Processing Record 13 of Set 6 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | vostok
# Processing Record 15 of Set 6 | kuleshovka
# Processing Record 16 of Set 6 | serebryansk
# Processing Record 17 of Set 6 | nemuro
# Processing Record 18 of Set 6 | umea
# Processing Record 19 of Set 6 | impfondo
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | isla mujeres
# Processing Record 22 of Set 6 | san juan del sur
# Processing Record 23 of Set 6 | panama city
# Processing Record 24 of Set 6 | binga
# Processing Record 25 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 6 | vilhena
# Processing Record 27 of Set 6 | kahului
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | henties bay
# Processing Record 30 of Set 6 | caravelas
# Processing Record 31 of Set 6 | bassano
# Processing Record 32 of Set 6 | juneau
# Processing Record 33 of Set 6 | necochea
# Processing Record 34 of Set 6 | cayenne
# Processing Record 35 of Set 6 | kalabo
# Processing Record 36 of Set 6 | batemans bay
# Processing Record 37 of Set 6 | arawa
# Processing Record 38 of Set 6 | borovskoy
# Processing Record 39 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 40 of Set 6 | palatka
# Processing Record 41 of Set 6 | abu kamal
# Processing Record 42 of Set 6 | balgazyn
# Processing Record 43 of Set 6 | la rochelle
# Processing Record 44 of Set 6 | quatre cocos
# Processing Record 45 of Set 6 | deshnok
# Processing Record 46 of Set 6 | kpandu
# Processing Record 47 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 6 | walvis bay
# Processing Record 49 of Set 6 | santa isabel do rio negro
# Processing Record 50 of Set 6 | atar
# Processing Record 1 of Set 7 | ixtapa
# Processing Record 2 of Set 7 | bang krathum
# Processing Record 3 of Set 7 | yenagoa
# Processing Record 4 of Set 7 | viseu
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | lorengau
# Processing Record 7 of Set 7 | paamiut
# Processing Record 8 of Set 7 | gaya
# Processing Record 9 of Set 7 | summerside
# Processing Record 10 of Set 7 | kundiawa
# Processing Record 11 of Set 7 | grindavik
# Processing Record 12 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 13 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 7 | belmonte
# Processing Record 15 of Set 7 | sarh
# Processing Record 16 of Set 7 | gomez palacio
# Processing Record 17 of Set 7 | plettenberg bay
# Processing Record 18 of Set 7 | itupiranga
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | saint-joseph
# Processing Record 21 of Set 7 | moose factory
# Processing Record 22 of Set 7 | medicine hat
# Processing Record 23 of Set 7 | derzhavinsk
# Processing Record 24 of Set 7 | port lincoln
# Processing Record 25 of Set 7 | manokwari
# Processing Record 26 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 7 | alice springs
# Processing Record 28 of Set 7 | yerbogachen
# Processing Record 29 of Set 7 | mwinilunga
# Processing Record 30 of Set 7 | rylsk
# Processing Record 31 of Set 7 | liepaja
# Processing Record 32 of Set 7 | peniche
# Processing Record 33 of Set 7 | gat
# Processing Record 34 of Set 7 | buchanan
# Processing Record 35 of Set 7 | narsaq
# Processing Record 36 of Set 7 | anadia
# Processing Record 37 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 7 | olafsvik
# Processing Record 39 of Set 7 | klaksvik
# Processing Record 40 of Set 7 | kismayo
# Processing Record 41 of Set 7 | voh
# Processing Record 42 of Set 7 | fortuna
# Processing Record 43 of Set 7 | ketchikan
# Processing Record 44 of Set 7 | acarau
# Processing Record 45 of Set 7 | saint-lo
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 7 | egvekinot
# Processing Record 49 of Set 7 | san jose
# Processing Record 50 of Set 7 | dronninglund
# Processing Record 1 of Set 8 | guayaquil
# Processing Record 2 of Set 8 | ouadda
# Processing Record 3 of Set 8 | ketchenery
# City not found. Skipping...
# Processing Record 4 of Set 8 | east london
# Processing Record 5 of Set 8 | aklavik
# Processing Record 6 of Set 8 | vryburg
# Processing Record 7 of Set 8 | cedar city
# Processing Record 8 of Set 8 | jacareacanga
# Processing Record 9 of Set 8 | lichuan
# Processing Record 10 of Set 8 | alekseyevka
# Processing Record 11 of Set 8 | aksarka
# Processing Record 12 of Set 8 | canavieiras
# Processing Record 13 of Set 8 | pevek
# Processing Record 14 of Set 8 | hervey bay
# Processing Record 15 of Set 8 | vershino-darasunskiy
# Processing Record 16 of Set 8 | vestmanna
# Processing Record 17 of Set 8 | toropets
# Processing Record 18 of Set 8 | binzhou
# Processing Record 19 of Set 8 | hamilton
# Processing Record 20 of Set 8 | qaqortoq
# Processing Record 21 of Set 8 | lebu
# Processing Record 22 of Set 8 | te horo
# Processing Record 23 of Set 8 | bereslavka
# Processing Record 24 of Set 8 | pitimbu
# Processing Record 25 of Set 8 | avera
# Processing Record 26 of Set 8 | namibe
# Processing Record 27 of Set 8 | turan
# Processing Record 28 of Set 8 | marabba
# Processing Record 29 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 30 of Set 8 | belaya kholunitsa
# Processing Record 31 of Set 8 | mahibadhoo
# Processing Record 32 of Set 8 | whitehorse
# Processing Record 33 of Set 8 | miguel hidalgo
# Processing Record 34 of Set 8 | riyadh
# Processing Record 35 of Set 8 | pokrovskoye
# Processing Record 36 of Set 8 | borogontsy
# Processing Record 37 of Set 8 | bowen
# Processing Record 38 of Set 8 | salym
# Processing Record 39 of Set 8 | laguna
# Processing Record 40 of Set 8 | namatanai
# Processing Record 41 of Set 8 | birobidzhan
# Processing Record 42 of Set 8 | teacapan
# Processing Record 43 of Set 8 | hualmay
# Processing Record 44 of Set 8 | kiama
# Processing Record 45 of Set 8 | cockburn town
# Processing Record 46 of Set 8 | hemnesberget
# Processing Record 47 of Set 8 | pasni
# Processing Record 48 of Set 8 | barroui
# City not found. Skipping...
# Processing Record 49 of Set 8 | buraydah
# Processing Record 50 of Set 8 | micheweni
# Processing Record 1 of Set 9 | benguela
# Processing Record 2 of Set 9 | morganton
# Processing Record 3 of Set 9 | saldanha
# Processing Record 4 of Set 9 | estelle
# Processing Record 5 of Set 9 | nouakchott
# Processing Record 6 of Set 9 | katsuura
# Processing Record 7 of Set 9 | lishu
# Processing Record 8 of Set 9 | sri aman
# Processing Record 9 of Set 9 | aykino
# Processing Record 10 of Set 9 | zhanaozen
# Processing Record 11 of Set 9 | lynchburg
# Processing Record 12 of Set 9 | pascagoula
# Processing Record 13 of Set 9 | olinda
# Processing Record 14 of Set 9 | batticaloa
# Processing Record 15 of Set 9 | tromso
# Processing Record 16 of Set 9 | sogdiondon
# City not found. Skipping...
# Processing Record 17 of Set 9 | jagdalpur
# Processing Record 18 of Set 9 | husavik
# Processing Record 19 of Set 9 | zabaykalsk
# Processing Record 20 of Set 9 | celestun
# Processing Record 21 of Set 9 | oranjemund
# Processing Record 22 of Set 9 | energetik
# Processing Record 23 of Set 9 | tamandare
# Processing Record 24 of Set 9 | yining
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 9 | bonthe
# Processing Record 28 of Set 9 | denpasar
# Processing Record 29 of Set 9 | tura
# Processing Record 30 of Set 9 | hammerfest
# Processing Record 31 of Set 9 | faanui
# Processing Record 32 of Set 9 | salair
# Processing Record 33 of Set 9 | araouane
# Processing Record 34 of Set 9 | gao
# Processing Record 35 of Set 9 | ippy
# Processing Record 36 of Set 9 | porto novo
# Processing Record 37 of Set 9 | barra patuca
# Processing Record 38 of Set 9 | severomuysk
# Processing Record 39 of Set 9 | kailua
# Processing Record 40 of Set 9 | santa rosa
# Processing Record 41 of Set 9 | baruun-urt
# Processing Record 42 of Set 9 | nhulunbuy
# Processing Record 43 of Set 9 | dir
# Processing Record 44 of Set 9 | north platte
# Processing Record 45 of Set 9 | balkanabat
# Processing Record 46 of Set 9 | batagay-alyta
# Processing Record 47 of Set 9 | cartago
# Processing Record 48 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 9 | leshukonskoye
# Processing Record 50 of Set 9 | boyuibe
# Processing Record 1 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 10 | vieux fort
# Processing Record 3 of Set 10 | digoin
# Processing Record 4 of Set 10 | zherdevka
# Processing Record 5 of Set 10 | jackson
# Processing Record 6 of Set 10 | ancud
# Processing Record 7 of Set 10 | qasigiannguit
# Processing Record 8 of Set 10 | viedma
# Processing Record 9 of Set 10 | tautira
# Processing Record 10 of Set 10 | maneromango
# Processing Record 11 of Set 10 | angra
# City not found. Skipping...
# Processing Record 12 of Set 10 | bandarbeyla
# Processing Record 13 of Set 10 | moerai
# Processing Record 14 of Set 10 | nuevo imperial
# Processing Record 15 of Set 10 | puerto leguizamo
# Processing Record 16 of Set 10 | garden city
# Processing Record 17 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 10 | saint-georges
# Processing Record 19 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 20 of Set 10 | akyab
# Processing Record 21 of Set 10 | ballina
# Processing Record 22 of Set 10 | thaton
# Processing Record 23 of Set 10 | sao filipe
# Processing Record 24 of Set 10 | esna
# Processing Record 25 of Set 10 | kokopo
# Processing Record 26 of Set 10 | richards bay
# Processing Record 27 of Set 10 | khatanga
# Processing Record 28 of Set 10 | keetmanshoop
# Processing Record 29 of Set 10 | arica
# Processing Record 30 of Set 10 | sorong
# Processing Record 31 of Set 10 | omboue
# Processing Record 32 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 33 of Set 10 | kikuyu
# Processing Record 34 of Set 10 | saint-augustin
# Processing Record 35 of Set 10 | rio claro
# Processing Record 36 of Set 10 | medina del campo
# Processing Record 37 of Set 10 | ostrovnoy
# Processing Record 38 of Set 10 | esfarayen
# Processing Record 39 of Set 10 | bouar
# Processing Record 40 of Set 10 | gbadolite
# Processing Record 41 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 10 | ratnagiri
# Processing Record 43 of Set 10 | fairbanks
# Processing Record 44 of Set 10 | komsomolskiy
# Processing Record 45 of Set 10 | taoudenni
# Processing Record 46 of Set 10 | kalmunai
# Processing Record 47 of Set 10 | kumluca
# Processing Record 48 of Set 10 | santa maria da vitoria
# Processing Record 49 of Set 10 | kaoma
# Processing Record 50 of Set 10 | colinas
# Processing Record 1 of Set 11 | evensk
# Processing Record 2 of Set 11 | camacha
# Processing Record 3 of Set 11 | ndele
# Processing Record 4 of Set 11 | hofn
# Processing Record 5 of Set 11 | zhangye
# Processing Record 6 of Set 11 | ariquemes
# Processing Record 7 of Set 11 | saint anthony
# Processing Record 8 of Set 11 | broken hill
# Processing Record 9 of Set 11 | borehamwood
# Processing Record 10 of Set 11 | dauriya
# Processing Record 11 of Set 11 | bilma
# Processing Record 12 of Set 11 | muros
# Processing Record 13 of Set 11 | el estor
# Processing Record 14 of Set 11 | vao
# Processing Record 15 of Set 11 | coihaique
# Processing Record 16 of Set 11 | zhezkazgan
# Processing Record 17 of Set 11 | jeremie
# Processing Record 18 of Set 11 | launceston
# Processing Record 19 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 11 | dafeng
# Processing Record 21 of Set 11 | autazes
# Processing Record 22 of Set 11 | soyo
# Processing Record 23 of Set 11 | harlingen
# Processing Record 24 of Set 11 | srednekolymsk
# Processing Record 25 of Set 11 | conselheiro lafaiete
# Processing Record 26 of Set 11 | visby
# Processing Record 27 of Set 11 | college
# Processing Record 28 of Set 11 | talnakh
# Processing Record 29 of Set 11 | kigoma
# Processing Record 30 of Set 11 | vitim
# Processing Record 31 of Set 11 | sfantu gheorghe
# Processing Record 32 of Set 11 | miranda
# Processing Record 33 of Set 11 | humaita
# Processing Record 34 of Set 11 | port-gentil
# Processing Record 35 of Set 11 | zyryanka
# Processing Record 36 of Set 11 | bulawayo
# Processing Record 37 of Set 11 | beisfjord
# Processing Record 38 of Set 11 | bethel
# Processing Record 39 of Set 11 | bungu
# Processing Record 40 of Set 11 | belyy yar
# Processing Record 41 of Set 11 | ho chi minh city
# Processing Record 42 of Set 11 | bud
# Processing Record 43 of Set 11 | mehamn
# Processing Record 44 of Set 11 | turukhansk
# Processing Record 45 of Set 11 | vila
# Processing Record 46 of Set 11 | constantine
# Processing Record 47 of Set 11 | banda aceh
# Processing Record 48 of Set 11 | winnemucca
# Processing Record 49 of Set 11 | cascais
# Processing Record 50 of Set 11 | nador
# Processing Record 1 of Set 12 | namtsy
# Processing Record 2 of Set 12 | djambala
# Processing Record 3 of Set 12 | kuryk
# Processing Record 4 of Set 12 | grojec
# Processing Record 5 of Set 12 | elos
# Processing Record 6 of Set 12 | talara
# Processing Record 7 of Set 12 | grand gaube
# Processing Record 8 of Set 12 | navoi
# Processing Record 9 of Set 12 | southbridge
# Processing Record 10 of Set 12 | kolpashevo
# Processing Record 11 of Set 12 | acapulco
# Processing Record 12 of Set 12 | kaa-khem
# Processing Record 13 of Set 12 | takoradi
# Processing Record 14 of Set 12 | dong hoi
# Processing Record 15 of Set 12 | agadez
# Processing Record 16 of Set 12 | yarada
# Processing Record 17 of Set 12 | davila
# Processing Record 18 of Set 12 | wanaka
# Processing Record 19 of Set 12 | taunsa
# Processing Record 20 of Set 12 | maues
# Processing Record 21 of Set 12 | alofi
# Processing Record 22 of Set 12 | kamalasai
# Processing Record 23 of Set 12 | bubaque
# Processing Record 24 of Set 12 | palaikastron
# Processing Record 25 of Set 12 | tual
# Processing Record 26 of Set 12 | port macquarie
# Processing Record 27 of Set 12 | chornukhy
# Processing Record 28 of Set 12 | isangel
# Processing Record 29 of Set 12 | sambava
# Processing Record 30 of Set 12 | taft
# Processing Record 31 of Set 12 | nome
# Processing Record 32 of Set 12 | pilikwe
# Processing Record 33 of Set 12 | remiremont
# Processing Record 34 of Set 12 | inzhavino
# Processing Record 35 of Set 12 | khorramshahr
# Processing Record 36 of Set 12 | katsina
# Processing Record 37 of Set 12 | mityana
# Processing Record 38 of Set 12 | mahanje
# Processing Record 39 of Set 12 | biak
# Processing Record 40 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 12 | ihosy
# Processing Record 43 of Set 12 | bosaso
# Processing Record 44 of Set 12 | edmundston
# Processing Record 45 of Set 12 | holoby
# Processing Record 46 of Set 12 | jose bonifacio
# Processing Record 47 of Set 12 | mount darwin
# Processing Record 48 of Set 12 | makakilo city
# Processing Record 49 of Set 12 | ahuimanu
# Processing Record 50 of Set 12 | sinnamary
# Processing Record 1 of Set 13 | coria
# Processing Record 2 of Set 13 | rio grande
# Processing Record 3 of Set 13 | lensk
# Processing Record 4 of Set 13 | barceloneta
# Processing Record 5 of Set 13 | kodinsk
# Processing Record 6 of Set 13 | ardakan
# Processing Record 7 of Set 13 | sibolga
# Processing Record 8 of Set 13 | kargil
# Processing Record 9 of Set 13 | maragogi
# Processing Record 10 of Set 13 | beringovskiy
# Processing Record 11 of Set 13 | rapid valley
# Processing Record 12 of Set 13 | sanchor
# Processing Record 13 of Set 13 | prambanan
# City not found. Skipping...
# Processing Record 14 of Set 13 | chepen
# Processing Record 15 of Set 13 | axim
# Processing Record 16 of Set 13 | aksu
# Processing Record 17 of Set 13 | kisac
# Processing Record 18 of Set 13 | fort nelson
# Processing Record 19 of Set 13 | kidal
# Processing Record 20 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 21 of Set 13 | aswan
# Processing Record 22 of Set 13 | yaan
# Processing Record 23 of Set 13 | chuy
# Processing Record 24 of Set 13 | the valley
# Processing Record 25 of Set 13 | lamar
# Processing Record 26 of Set 13 | westport
# Processing Record 27 of Set 13 | comodoro rivadavia
# Processing Record 28 of Set 13 | atikokan
# Processing Record 29 of Set 13 | aras
# Processing Record 30 of Set 13 | kyra
# Processing Record 31 of Set 13 | anyama
# Processing Record 32 of Set 13 | ukiah
# Processing Record 33 of Set 13 | chandigarh
# Processing Record 34 of Set 13 | porosozero
# Processing Record 35 of Set 13 | haines junction
# Processing Record 36 of Set 13 | goundam
# Processing Record 37 of Set 13 | si satchanalai
# Processing Record 38 of Set 13 | barra do garcas
# Processing Record 39 of Set 13 | lata
# Processing Record 40 of Set 13 | itarema
# Processing Record 41 of Set 13 | gibsons
# Processing Record 42 of Set 13 | charters towers
# Processing Record 43 of Set 13 | diamantino
# Processing Record 44 of Set 13 | pangnirtung
# Processing Record 45 of Set 13 | rabaul
# Processing Record 46 of Set 13 | inuvik
# Processing Record 47 of Set 13 | campbell river
# Processing Record 48 of Set 13 | gawler
# Processing Record 49 of Set 13 | rock springs
# Processing Record 50 of Set 13 | brownwood
# Processing Record 1 of Set 14 | kayunga
# Processing Record 2 of Set 14 | batu
# Processing Record 3 of Set 14 | neryungri
# Processing Record 4 of Set 14 | gainesville
# Processing Record 5 of Set 14 | dunedin
# Processing Record 6 of Set 14 | slyudyanka
# Processing Record 7 of Set 14 | lazarevac
# Processing Record 8 of Set 14 | meadow lake
# Processing Record 9 of Set 14 | sungaipenuh
# Processing Record 10 of Set 14 | kieta
# Processing Record 11 of Set 14 | hay river
# Processing Record 12 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 14 | orje
# Processing Record 14 of Set 14 | ho
# City not found. Skipping...
# Processing Record 15 of Set 14 | megion
# Processing Record 16 of Set 14 | arisvi
# Processing Record 17 of Set 14 | poum
# Processing Record 18 of Set 14 | semporna
# Processing Record 19 of Set 14 | abnub
# Processing Record 20 of Set 14 | altona
# Processing Record 21 of Set 14 | zaraza
# Processing Record 22 of Set 14 | houston
# Processing Record 23 of Set 14 | san lorenzo
# Processing Record 24 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 14 | yulara
# Processing Record 26 of Set 14 | rancho palos verdes
# Processing Record 27 of Set 14 | ustka
# Processing Record 28 of Set 14 | carnot
# Processing Record 29 of Set 14 | nantucket
# Processing Record 30 of Set 14 | nanakuli
# Processing Record 31 of Set 14 | innisfail
# Processing Record 32 of Set 14 | victor harbor
# Processing Record 33 of Set 14 | salmas
# Processing Record 34 of Set 14 | waipawa
# Processing Record 35 of Set 14 | coos bay
# Processing Record 36 of Set 14 | nizwa
# Processing Record 37 of Set 14 | nola
# Processing Record 38 of Set 14 | besikduzu
# Processing Record 39 of Set 14 | pori
# Processing Record 40 of Set 14 | tecoanapa
# Processing Record 41 of Set 14 | dali
# Processing Record 42 of Set 14 | beruwala
# Processing Record 43 of Set 14 | erenhot
# Processing Record 44 of Set 14 | tuy hoa
# Processing Record 45 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 46 of Set 14 | dumas
# Processing Record 47 of Set 14 | praia da vitoria
# Processing Record 48 of Set 14 | camacupa
# Processing Record 49 of Set 14 | ebeltoft
# Processing Record 50 of Set 14 | babu
# Processing Record 1 of Set 15 | alora
# Processing Record 2 of Set 15 | miandrivazo
# Processing Record 3 of Set 15 | eureka
# Processing Record 4 of Set 15 | san buenaventura
# Processing Record 5 of Set 15 | kavaratti
# Processing Record 6 of Set 15 | broome
# Processing Record 7 of Set 15 | burnie
# Processing Record 8 of Set 15 | general roca
# Processing Record 9 of Set 15 | praya
# Processing Record 10 of Set 15 | ndola
# Processing Record 11 of Set 15 | kutum
# Processing Record 12 of Set 15 | kupang
# Processing Record 13 of Set 15 | yinchuan
# Processing Record 14 of Set 15 | sakakah
# Processing Record 15 of Set 15 | santo antonio do ica
# Processing Record 16 of Set 15 | semibratovo
# Processing Record 17 of Set 15 | vilyuysk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
city_data
# Out:
# [{'City': 'busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 290.3,
#   'Humidity': 55,
#   'Cloudiness': 79,
#   'Wind Speed': 9.02,
#   'Current Description': 'broken clouds'},
#  {'City': 'mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 287.86,
#   'Humidity': 89,
#   'Cloudiness': 97,
#   'Wind Speed': 1.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'concepcion del oro',
#   'Country': 'MX',
#   'Lat': 24.6333,
#   'Lng': -101.4167,
#   'Max Temp': 283.36,
#   'Humidity': 70,
#   'Cloudiness': 17,
#   'Wind Speed': 2.9,
#   'Current Description': 'few clouds'},
#  {'City': 'lagoa',
#   'Country': 'PT',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 288.65,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 9.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'nishihara',
#   'Country': 'JP',
#   'Lat': 26.1842,
#   'Lng': 127.7558,
#   'Max Temp': 298.96,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Current Description': 'light rain'},
#  {'City': 'thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 263.24,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Current Description': 'light snow'},
#  {'City': 'mayumba',
#   'Country': 'GA',
#   'Lat': -3.432,
#   'Lng': 10.6554,
#   'Max Temp': 296.89,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.09,
#   'Current Description': 'moderate rain'},
#  {'City': 'nadym',
#   'Country': 'RU',
#   'Lat': 65.5333,
#   'Lng': 72.5167,
#   'Max Temp': 255.7,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 5.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'saint-pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 298.97,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Current Description': 'clear sky'},
#  {'City': 'port alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 292.69,
#   'Humidity': 79,
#   'Cloudiness': 88,
#   'Wind Speed': 2.24,
#   'Current Description': 'overcast clouds'},
#  {'City': 'tongliao',
#   'Country': 'CN',
#   'Lat': 43.6125,
#   'Lng': 122.2653,
#   'Max Temp': 278.56,
#   'Humidity': 62,
#   'Cloudiness': 46,
#   'Wind Speed': 4.42,
#   'Current Description': 'scattered clouds'},
#  {'City': 'san cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 291.64,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 269.16,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Current Description': 'clear sky'},
#  {'City': 'galveston',
#   'Country': 'US',
#   'Lat': 29.3669,
#   'Lng': -94.9669,
#   'Max Temp': 283.69,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 0.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'camopi',
#   'Country': 'GF',
#   'Lat': 3.1655,
#   'Lng': -52.3158,
#   'Max Temp': 293.91,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 0.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'norman wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 252.17,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'severo-kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 274.29,
#   'Humidity': 67,
#   'Cloudiness': 99,
#   'Wind Speed': 2.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 265.15,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Current Description': 'few clouds'},
#  {'City': 'rio tuba',
#   'Country': 'PH',
#   'Lat': 8.5061,
#   'Lng': 117.4317,
#   'Max Temp': 302.08,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.62,
#   'Current Description': 'light rain'},
#  {'City': 'kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 279.88,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'prainha',
#   'Country': 'BR',
#   'Lat': -1.8,
#   'Lng': -53.48,
#   'Max Temp': 297.08,
#   'Humidity': 68,
#   'Cloudiness': 89,
#   'Wind Speed': 1.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 284.96,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Current Description': 'clear sky'},
#  {'City': 'ponta do sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 294.1,
#   'Humidity': 82,
#   'Cloudiness': 88,
#   'Wind Speed': 3.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'bodden town',
#   'Country': 'KY',
#   'Lat': 19.2833,
#   'Lng': -81.25,
#   'Max Temp': 300.89,
#   'Humidity': 79,
#   'Cloudiness': 27,
#   'Wind Speed': 7.35,
#   'Current Description': 'scattered clouds'},
#  {'City': 'san carlos de bariloche',
#   'Country': 'AR',
#   'Lat': -41.1456,
#   'Lng': -71.3082,
#   'Max Temp': 281.01,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Current Description': 'clear sky'},
#  {'City': 'hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 288.85,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 9.26,
#   'Current Description': 'few clouds'},
#  {'City': 'punta arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 281.21,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Current Description': 'clear sky'},
#  {'City': 'hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 290.82,
#   'Humidity': 64,
#   'Cloudiness': 95,
#   'Wind Speed': 3.26,
#   'Current Description': 'overcast clouds'},
#  {'City': 'georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 304.11,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Current Description': 'few clouds'},
#  {'City': 'vanavara',
#   'Country': 'RU',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 263.43,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Current Description': 'light snow'},
#  {'City': 'tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 246.47,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 2.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 293.38,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 7.72,
#   'Current Description': 'broken clouds'},
#  {'City': 'rabupura',
#   'Country': 'IN',
#   'Lat': 28.25,
#   'Lng': 77.6,
#   'Max Temp': 297.72,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 5.47,
#   'Current Description': 'clear sky'},
#  {'City': 'ambilobe',
#   'Country': 'MG',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 302.59,
#   'Humidity': 57,
#   'Cloudiness': 98,
#   'Wind Speed': 0.81,
#   'Current Description': 'light rain'},
#  {'City': 'ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 265.16,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'light snow'},
#  {'City': 'kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 302.04,
#   'Humidity': 71,
#   'Cloudiness': 84,
#   'Wind Speed': 3.72,
#   'Current Description': 'light rain'},
#  {'City': 'vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 297.24,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Current Description': 'few clouds'},
#  {'City': 'coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 287,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Current Description': 'few clouds'},
#  {'City': 'saint george',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 277.01,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 0.45,
#   'Current Description': 'clear sky'},
#  {'City': 'luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 291.24,
#   'Humidity': 65,
#   'Cloudiness': 11,
#   'Wind Speed': 5.31,
#   'Current Description': 'few clouds'},
#  {'City': 'port blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 299.17,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Current Description': 'broken clouds'},
#  {'City': 'lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 274.04,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Current Description': 'snow'},
#  {'City': 'albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 276.14,
#   'Humidity': 90,
#   'Cloudiness': 55,
#   'Wind Speed': 4.18,
#   'Current Description': 'broken clouds'},
#  {'City': 'kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 292.53,
#   'Humidity': 58,
#   'Cloudiness': 80,
#   'Wind Speed': 4.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 283.47,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Current Description': 'clear sky'},
#  {'City': 'san patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 284.73,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 3.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'port elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 293.76,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Current Description': 'few clouds'},
#  {'City': 'hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 295.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Current Description': 'overcast clouds'},
#  {'City': 'provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 273.96,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 3.55,
#   'Current Description': 'snow'},
#  {'City': 'shiringushi',
#   'Country': 'RU',
#   'Lat': 53.8485,
#   'Lng': 42.7676,
#   'Max Temp': 270.39,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.35,
#   'Current Description': 'light snow'},
#  {'City': 'valparaiso',
#   'Country': 'CL',
#   'Lat': -33.0393,
#   'Lng': -71.6273,
#   'Max Temp': 285.95,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Current Description': 'scattered clouds'},
#  {'City': 'mar del plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 290.16,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58,
#   'Current Description': 'moderate rain'},
#  {'City': 'antalaha',
#   'Country': 'MG',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 297.92,
#   'Humidity': 80,
#   'Cloudiness': 19,
#   'Wind Speed': 1.57,
#   'Current Description': 'light rain'},
#  {'City': 'qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 250.9,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 2.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 288.04,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 291.94,
#   'Humidity': 68,
#   'Cloudiness': 49,
#   'Wind Speed': 7.19,
#   'Current Description': 'scattered clouds'},
#  {'City': 'rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 296.58,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 8.19,
#   'Current Description': 'moderate rain'},
#  {'City': 'ekibastuz',
#   'Country': 'KZ',
#   'Lat': 51.6667,
#   'Lng': 75.3667,
#   'Max Temp': 268.25,
#   'Humidity': 57,
#   'Cloudiness': 98,
#   'Wind Speed': 8,
#   'Current Description': 'overcast clouds'},
#  {'City': 'bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 289.98,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 2.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'taos',
#   'Country': 'US',
#   'Lat': 36.4072,
#   'Lng': -105.5731,
#   'Max Temp': 266.07,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Current Description': 'clear sky'},
#  {'City': 'chiang rai',
#   'Country': 'TH',
#   'Lat': 19.9167,
#   'Lng': 99.9167,
#   'Max Temp': 303.14,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Current Description': 'broken clouds'},
#  {'City': 'tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 286.38,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 255.89,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.04,
#   'Current Description': 'overcast clouds'},
#  {'City': 'karratha',
#   'Country': 'AU',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 299.77,
#   'Humidity': 44,
#   'Cloudiness': 17,
#   'Wind Speed': 9.1,
#   'Current Description': 'few clouds'},
#  {'City': 'iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 261,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Current Description': 'light snow'},
#  {'City': 'vanimo',
#   'Country': 'PG',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 302.39,
#   'Humidity': 70,
#   'Cloudiness': 92,
#   'Wind Speed': 3.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 282.54,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.02,
#   'Current Description': 'light rain'},
#  {'City': 'butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 300.76,
#   'Humidity': 77,
#   'Cloudiness': 42,
#   'Wind Speed': 5.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'goure',
#   'Country': 'NE',
#   'Lat': 13.9835,
#   'Lng': 10.2704,
#   'Max Temp': 291.71,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 3.88,
#   'Current Description': 'clear sky'},
#  {'City': 'puerto ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 292.9,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 0.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 297.43,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.93,
#   'Current Description': 'light rain'},
#  {'City': 'wad rawah',
#   'Country': 'SD',
#   'Lat': 15.1603,
#   'Lng': 33.1397,
#   'Max Temp': 297.38,
#   'Humidity': 26,
#   'Cloudiness': 11,
#   'Wind Speed': 6.99,
#   'Current Description': 'few clouds'},
#  {'City': 'elko',
#   'Country': 'US',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': 264.29,
#   'Humidity': 88,
#   'Cloudiness': 9,
#   'Wind Speed': 0.94,
#   'Current Description': 'clear sky'},
#  {'City': 'abu dhabi',
#   'Country': 'AE',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 302.16,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'faya',
#   'Country': 'SA',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 293.21,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 1.18,
#   'Current Description': 'clear sky'},
#  {'City': 'oshkosh',
#   'Country': 'US',
#   'Lat': 44.0247,
#   'Lng': -88.5426,
#   'Max Temp': 271.81,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 1.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'new norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 288.66,
#   'Humidity': 50,
#   'Cloudiness': 97,
#   'Wind Speed': 1.79,
#   'Current Description': 'overcast clouds'},
#  {'City': 'cachoeira do sul',
#   'Country': 'BR',
#   'Lat': -30.0392,
#   'Lng': -52.8939,
#   'Max Temp': 288.9,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 1.86,
#   'Current Description': 'clear sky'},
#  {'City': 'sidi ali',
#   'Country': 'DZ',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 290.84,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 9.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 247.87,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 2.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'sechura',
#   'Country': 'PE',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 291.47,
#   'Humidity': 81,
#   'Cloudiness': 91,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'santa fe',
#   'Country': 'AR',
#   'Lat': -31.6333,
#   'Lng': -60.7,
#   'Max Temp': 296.47,
#   'Humidity': 58,
#   'Cloudiness': 82,
#   'Wind Speed': 0.89,
#   'Current Description': 'light rain'},
#  {'City': 'kupino',
#   'Country': 'RU',
#   'Lat': 54.3663,
#   'Lng': 77.2981,
#   'Max Temp': 264.37,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Current Description': 'overcast clouds'},
#  {'City': 'dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 302.06,
#   'Humidity': 75,
#   'Cloudiness': 73,
#   'Wind Speed': 5.28,
#   'Current Description': 'broken clouds'},
#  {'City': 'ribeira grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 289.14,
#   'Humidity': 64,
#   'Cloudiness': 63,
#   'Wind Speed': 2.68,
#   'Current Description': 'broken clouds'},
#  {'City': 'orlik',
#   'Country': 'RU',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 266.27,
#   'Humidity': 72,
#   'Cloudiness': 95,
#   'Wind Speed': 1.21,
#   'Current Description': 'overcast clouds'},
#  {'City': 'leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 258.72,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 0.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 286.89,
#   'Humidity': 83,
#   'Cloudiness': 32,
#   'Wind Speed': 5.31,
#   'Current Description': 'scattered clouds'},
#  {'City': 'mubi',
#   'Country': 'NG',
#   'Lat': 10.2676,
#   'Lng': 13.2644,
#   'Max Temp': 294.28,
#   'Humidity': 37,
#   'Cloudiness': 95,
#   'Wind Speed': 0.88,
#   'Current Description': 'overcast clouds'},
#  {'City': 'rio gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 285.18,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Current Description': 'clear sky'},
#  {'City': 'ponta delgada',
#   'Country': 'PT',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 289.55,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Current Description': 'scattered clouds'},
#  {'City': 'scottsbluff',
#   'Country': 'US',
#   'Lat': 41.8666,
#   'Lng': -103.6672,
#   'Max Temp': 274.28,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Current Description': 'overcast clouds'},
#  {'City': 'kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 297.33,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Current Description': 'broken clouds'},
#  {'City': 'huarmey',
#   'Country': 'PE',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 290.8,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 293.8,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 8.36,
#   'Current Description': 'clear sky'},
#  {'City': 'tricase',
#   'Country': 'IT',
#   'Lat': 39.9304,
#   'Lng': 18.3553,
#   'Max Temp': 290.11,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'havoysund',
#   'Country': 'NO',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 279.28,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 6.46,
#   'Current Description': 'overcast clouds'},
#  {'City': 'padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 297.18,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Current Description': 'moderate rain'},
#  {'City': 'cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 290.75,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 1.62,
#   'Current Description': 'clear sky'},
#  {'City': 'bichura',
#   'Country': 'RU',
#   'Lat': 50.5881,
#   'Lng': 107.6022,
#   'Max Temp': 274.09,
#   'Humidity': 74,
#   'Cloudiness': 13,
#   'Wind Speed': 0.91,
#   'Current Description': 'few clouds'},
#  {'City': 'vangaindrano',
#   'Country': 'MG',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 299.8,
#   'Humidity': 69,
#   'Cloudiness': 85,
#   'Wind Speed': 3.6,
#   'Current Description': 'light rain'},
#  {'City': 'ucluelet',
#   'Country': 'CA',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 280.65,
#   'Humidity': 65,
#   'Cloudiness': 95,
#   'Wind Speed': 1.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'bambous virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 299.38,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 1.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'cape town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 292.65,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 8.75,
#   'Current Description': 'few clouds'},
#  {'City': 'mareeba',
#   'Country': 'AU',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 305.06,
#   'Humidity': 51,
#   'Cloudiness': 1,
#   'Wind Speed': 4.13,
#   'Current Description': 'clear sky'},
#  {'City': 'placido de castro',
#   'Country': 'BR',
#   'Lat': -10.3353,
#   'Lng': -67.1856,
#   'Max Temp': 295.17,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 0.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'honningsvag',
#   'Country': 'NO',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 279.01,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 5.14,
#   'Current Description': 'broken clouds'},
#  {'City': 'kijang',
#   'Country': 'KR',
#   'Lat': 35.2442,
#   'Lng': 129.2139,
#   'Max Temp': 291,
#   'Humidity': 35,
#   'Cloudiness': 7,
#   'Wind Speed': 1.38,
#   'Current Description': 'clear sky'},
#  {'City': 'jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 272.88,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Current Description': 'snow'},
#  {'City': 'kamaishi',
#   'Country': 'JP',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 281.69,
#   'Humidity': 51,
#   'Cloudiness': 24,
#   'Wind Speed': 1.42,
#   'Current Description': 'few clouds'},
#  {'City': 'segezha',
#   'Country': 'RU',
#   'Lat': 63.7415,
#   'Lng': 34.3222,
#   'Max Temp': 272.52,
#   'Humidity': 84,
#   'Cloudiness': 57,
#   'Wind Speed': 3.29,
#   'Current Description': 'broken clouds'},
#  {'City': 'santa cruz',
#   'Country': 'BO',
#   'Lat': -17.8,
#   'Lng': -63.1667,
#   'Max Temp': 294.85,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.06,
#   'Current Description': 'few clouds'},
#  {'City': 'hasaki',
#   'Country': 'JP',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 289.42,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 300.39,
#   'Humidity': 73,
#   'Cloudiness': 8,
#   'Wind Speed': 2.68,
#   'Current Description': 'clear sky'},
#  {'City': 'jesup',
#   'Country': 'US',
#   'Lat': 31.6074,
#   'Lng': -81.8854,
#   'Max Temp': 282.78,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'rocha',
#   'Country': 'UY',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 288.06,
#   'Humidity': 68,
#   'Cloudiness': 59,
#   'Wind Speed': 2.71,
#   'Current Description': 'broken clouds'},
#  {'City': 'kushikino',
#   'Country': 'JP',
#   'Lat': 31.7167,
#   'Lng': 130.2667,
#   'Max Temp': 290.42,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 301.8,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'clear sky'},
#  {'City': 'voyvozh',
#   'Country': 'RU',
#   'Lat': 62.892,
#   'Lng': 54.9635,
#   'Max Temp': 252.69,
#   'Humidity': 96,
#   'Cloudiness': 31,
#   'Wind Speed': 1.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 299.4,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 1.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'lazaro cardenas',
#   'Country': 'MX',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 297.06,
#   'Humidity': 91,
#   'Cloudiness': 45,
#   'Wind Speed': 1.89,
#   'Current Description': 'scattered clouds'},
#  {'City': 'yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 259.44,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Current Description': 'broken clouds'},
#  {'City': 'torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 275.79,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'taltal',
#   'Country': 'CL',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 288.98,
#   'Humidity': 88,
#   'Cloudiness': 56,
#   'Wind Speed': 1.13,
#   'Current Description': 'broken clouds'},
#  {'City': 'mankera',
#   'Country': 'PK',
#   'Lat': 31.3866,
#   'Lng': 71.4407,
#   'Max Temp': 298.61,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 2.26,
#   'Current Description': 'clear sky'},
#  {'City': 'koutsouras',
#   'Country': 'GR',
#   'Lat': 35.0339,
#   'Lng': 25.9469,
#   'Max Temp': 290.99,
#   'Humidity': 73,
#   'Cloudiness': 6,
#   'Wind Speed': 8.58,
#   'Current Description': 'clear sky'},
#  {'City': 'sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 279.09,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Current Description': 'clear sky'},
#  {'City': 'ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 290.45,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 297.36,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 1.54,
#   'Current Description': 'scattered clouds'},
#  {'City': 'dhidhdhoo',
#   'Country': 'MV',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 300.89,
#   'Humidity': 73,
#   'Cloudiness': 21,
#   'Wind Speed': 3.57,
#   'Current Description': 'few clouds'},
#  {'City': 'hovd',
#   'Country': 'MN',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 276.26,
#   'Humidity': 20,
#   'Cloudiness': 98,
#   'Wind Speed': 7.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'urusha',
#   'Country': 'RU',
#   'Lat': 54.05,
#   'Lng': 122.9,
#   'Max Temp': 263.91,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.24,
#   'Current Description': 'light snow'},
#  {'City': 'narok',
#   'Country': 'KE',
#   'Lat': -1.0783,
#   'Lng': 35.8601,
#   'Max Temp': 289.1,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.74,
#   'Current Description': 'light rain'},
#  {'City': 'gigmoto',
#   'Country': 'PH',
#   'Lat': 13.7796,
#   'Lng': 124.39,
#   'Max Temp': 300.33,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'balakliya',
#   'Country': 'UA',
#   'Lat': 49.4627,
#   'Lng': 36.8595,
#   'Max Temp': 278.47,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'entre rios',
#   'Country': 'BR',
#   'Lat': -11.9419,
#   'Lng': -38.0844,
#   'Max Temp': 293.96,
#   'Humidity': 99,
#   'Cloudiness': 49,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 239.51,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.64,
#   'Current Description': 'overcast clouds'},
#  {'City': 'avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 296.18,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Current Description': 'few clouds'},
#  {'City': 'atambua',
#   'Country': 'ID',
#   'Lat': -9.1061,
#   'Lng': 124.8925,
#   'Max Temp': 302.59,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Current Description': 'overcast clouds'},
#  {'City': 'gubkinskiy',
#   'Country': 'RU',
#   'Lat': 64.434,
#   'Lng': 76.5026,
#   'Max Temp': 258.11,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 6.86,
#   'Current Description': 'light snow'},
#  {'City': 'havelock',
#   'Country': 'US',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 284.14,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Current Description': 'clear sky'},
#  {'City': 'rosamorada',
#   'Country': 'MX',
#   'Lat': 22.1222,
#   'Lng': -105.2058,
#   'Max Temp': 292.19,
#   'Humidity': 76,
#   'Cloudiness': 5,
#   'Wind Speed': 1.39,
#   'Current Description': 'clear sky'},
#  {'City': 'brunico',
#   'Country': 'IT',
#   'Lat': 46.7958,
#   'Lng': 11.9364,
#   'Max Temp': 278.75,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 0.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'liverpool',
#   'Country': 'GB',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 282.12,
#   'Humidity': 95,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Current Description': 'light rain'},
#  {'City': 'bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 300.21,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 4.37,
#   'Current Description': 'light rain'},
#  {'City': 'havre-saint-pierre',
#   'Country': 'CA',
#   'Lat': 50.2334,
#   'Lng': -63.5986,
#   'Max Temp': 270.15,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Current Description': 'light snow'},
#  {'City': 'ville-marie',
#   'Country': 'CA',
#   'Lat': 47.3335,
#   'Lng': -79.433,
#   'Max Temp': 266.91,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.97,
#   'Current Description': 'light snow'},
#  {'City': 'lucapa',
#   'Country': 'AO',
#   'Lat': -8.4192,
#   'Lng': 20.7447,
#   'Max Temp': 294.7,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 298.7,
#   'Humidity': 76,
#   'Cloudiness': 6,
#   'Wind Speed': 7.1,
#   'Current Description': 'clear sky'},
#  {'City': 'upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 261.5,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'bonavista',
#   'Country': 'CA',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 273.72,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.2,
#   'Current Description': 'light snow'},
#  {'City': 'sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 301.21,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 2.5,
#   'Current Description': 'few clouds'},
#  {'City': 'portland',
#   'Country': 'US',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 277.23,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Current Description': 'clear sky'},
#  {'City': 'buala',
#   'Country': 'SB',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 300.96,
#   'Humidity': 77,
#   'Cloudiness': 67,
#   'Wind Speed': 1.09,
#   'Current Description': 'light rain'},
#  {'City': 'catuday',
#   'Country': 'PH',
#   'Lat': 16.2923,
#   'Lng': 119.8062,
#   'Max Temp': 302.52,
#   'Humidity': 62,
#   'Cloudiness': 17,
#   'Wind Speed': 3.14,
#   'Current Description': 'few clouds'},
#  {'City': 'saint-philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 298.92,
#   'Humidity': 67,
#   'Cloudiness': 24,
#   'Wind Speed': 3.81,
#   'Current Description': 'few clouds'},
#  {'City': 'izumo',
#   'Country': 'JP',
#   'Lat': 35.3667,
#   'Lng': 132.7667,
#   'Max Temp': 289.12,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Current Description': 'broken clouds'},
#  {'City': 'sao felix do xingu',
#   'Country': 'BR',
#   'Lat': -6.6447,
#   'Lng': -51.995,
#   'Max Temp': 294.81,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 0.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'de aar',
#   'Country': 'ZA',
#   'Lat': -30.6497,
#   'Lng': 24.0123,
#   'Max Temp': 296.37,
#   'Humidity': 18,
#   'Cloudiness': 40,
#   'Wind Speed': 4.09,
#   'Current Description': 'scattered clouds'},
#  {'City': 'umm kaddadah',
#   'Country': 'SD',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 295.48,
#   'Humidity': 24,
#   'Cloudiness': 95,
#   'Wind Speed': 7.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'vardo',
#   'Country': 'NO',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 277.14,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 253.82,
#   'Humidity': 98,
#   'Cloudiness': 92,
#   'Wind Speed': 0.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'kandrian',
#   'Country': 'PG',
#   'Lat': -6.2167,
#   'Lng': 149.55,
#   'Max Temp': 301.53,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.29,
#   'Current Description': 'light rain'},
#  {'City': 'nocupetaro',
#   'Country': 'MX',
#   'Lat': 19.05,
#   'Lng': -101.15,
#   'Max Temp': 294.68,
#   'Humidity': 64,
#   'Cloudiness': 19,
#   'Wind Speed': 1.73,
#   'Current Description': 'few clouds'},
#  {'City': 'moron',
#   'Country': 'AR',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 298.98,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 1.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'aykhal',
#   'Country': 'RU',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 242.04,
#   'Humidity': 100,
#   'Cloudiness': 92,
#   'Wind Speed': 1.97,
#   'Current Description': 'overcast clouds'},
#  {'City': 'meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 301.06,
#   'Humidity': 72,
#   'Cloudiness': 94,
#   'Wind Speed': 1.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'russell',
#   'Country': 'US',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 280.75,
#   'Humidity': 67,
#   'Cloudiness': 67,
#   'Wind Speed': 2.06,
#   'Current Description': 'broken clouds'},
#  {'City': 'touros',
#   'Country': 'BR',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 297.87,
#   'Humidity': 76,
#   'Cloudiness': 10,
#   'Wind Speed': 4.42,
#   'Current Description': 'clear sky'},
#  {'City': 'bathsheba',
#   'Country': 'BB',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 300.49,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 7.2,
#   'Current Description': 'scattered clouds'},
#  {'City': 'san andres',
#   'Country': 'CO',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 301.16,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Current Description': 'few clouds'},
#  {'City': 'muli',
#   'Country': 'MV',
#   'Lat': 2.9167,
#   'Lng': 73.5667,
#   'Max Temp': 300.78,
#   'Humidity': 76,
#   'Cloudiness': 83,
#   'Wind Speed': 5.79,
#   'Current Description': 'broken clouds'},
#  {'City': 'baker city',
#   'Country': 'US',
#   'Lat': 44.7749,
#   'Lng': -117.8344,
#   'Max Temp': 271.25,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'pattoki',
#   'Country': 'PK',
#   'Lat': 31.0167,
#   'Lng': 73.85,
#   'Max Temp': 298.99,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 4.19,
#   'Current Description': 'clear sky'},
#  {'City': 'castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 283.19,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 2.48,
#   'Current Description': 'clear sky'},
#  {'City': 'cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 256.16,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Current Description': 'light snow'},
#  {'City': 'bossangoa',
#   'Country': 'CF',
#   'Lat': 6.4926,
#   'Lng': 17.4552,
#   'Max Temp': 299.09,
#   'Humidity': 42,
#   'Cloudiness': 57,
#   'Wind Speed': 0.96,
#   'Current Description': 'broken clouds'},
#  {'City': 'airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 296.62,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 1.44,
#   'Current Description': 'light rain'},
#  {'City': 'gizo',
#   'Country': 'SB',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 302.02,
#   'Humidity': 69,
#   'Cloudiness': 30,
#   'Wind Speed': 1.43,
#   'Current Description': 'scattered clouds'},
#  {'City': 'sao joao de pirabas',
#   'Country': 'BR',
#   'Lat': -0.7747,
#   'Lng': -47.1772,
#   'Max Temp': 297.75,
#   'Humidity': 85,
#   'Cloudiness': 94,
#   'Wind Speed': 2.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 268.06,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Current Description': 'few clouds'},
#  {'City': 'uglovskoye',
#   'Country': 'RU',
#   'Lat': 51.3557,
#   'Lng': 80.1942,
#   'Max Temp': 270.24,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Current Description': 'overcast clouds'},
#  {'City': 'seoul',
#   'Country': 'KR',
#   'Lat': 37.5683,
#   'Lng': 126.9778,
#   'Max Temp': 289.81,
#   'Humidity': 40,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Current Description': 'few clouds'},
#  {'City': 'amarante do maranhao',
#   'Country': 'BR',
#   'Lat': -5.5667,
#   'Lng': -46.7422,
#   'Max Temp': 297.38,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 0.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 285.11,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'caledon',
#   'Country': 'ZA',
#   'Lat': -34.23,
#   'Lng': 19.4265,
#   'Max Temp': 289.3,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 2.67,
#   'Current Description': 'overcast clouds'},
#  {'City': 'flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 292.07,
#   'Humidity': 62,
#   'Cloudiness': 47,
#   'Wind Speed': 6.47,
#   'Current Description': 'scattered clouds'},
#  {'City': 'hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 300.79,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'salalah',
#   'Country': 'OM',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 302.2,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Current Description': 'clear sky'},
#  {'City': 'kuandian',
#   'Country': 'CN',
#   'Lat': 40.7286,
#   'Lng': 124.7847,
#   'Max Temp': 282.67,
#   'Humidity': 76,
#   'Cloudiness': 71,
#   'Wind Speed': 3.48,
#   'Current Description': 'broken clouds'},
#  {'City': 'naze',
#   'Country': 'JP',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 293.66,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Current Description': 'light rain'},
#  {'City': 'mogadouro',
#   'Country': 'PT',
#   'Lat': 41.3403,
#   'Lng': -6.7119,
#   'Max Temp': 286.62,
#   'Humidity': 87,
#   'Cloudiness': 86,
#   'Wind Speed': 6.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'tamworth',
#   'Country': 'GB',
#   'Lat': 52.634,
#   'Lng': -1.6959,
#   'Max Temp': 281.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.92,
#   'Current Description': 'light rain'},
#  {'City': 'presidencia roque saenz pena',
#   'Country': 'AR',
#   'Lat': -26.7852,
#   'Lng': -60.4388,
#   'Max Temp': 290.94,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 2.81,
#   'Current Description': 'clear sky'},
#  {'City': 'pacific grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 286.72,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'port hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 273.25,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 1.03,
#   'Current Description': 'scattered clouds'},
#  {'City': 'pauini',
#   'Country': 'BR',
#   'Lat': -7.7136,
#   'Lng': -66.9764,
#   'Max Temp': 295.08,
#   'Humidity': 98,
#   'Cloudiness': 96,
#   'Wind Speed': 0.68,
#   'Current Description': 'overcast clouds'},
#  {'City': 'berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 280.12,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'lloydminster',
#   'Country': 'CA',
#   'Lat': 53.2835,
#   'Lng': -110.0016,
#   'Max Temp': 263.27,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Current Description': 'overcast clouds'},
#  {'City': 'ormara',
#   'Country': 'PK',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 300.33,
#   'Humidity': 48,
#   'Cloudiness': 3,
#   'Wind Speed': 1.32,
#   'Current Description': 'clear sky'},
#  {'City': 'arraial do cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 294.84,
#   'Humidity': 73,
#   'Cloudiness': 3,
#   'Wind Speed': 4.97,
#   'Current Description': 'clear sky'},
#  {'City': 'mendeleyevskiy',
#   'Country': 'RU',
#   'Lat': 54.1528,
#   'Lng': 37.5822,
#   'Max Temp': 267.68,
#   'Humidity': 87,
#   'Cloudiness': 14,
#   'Wind Speed': 3.43,
#   'Current Description': 'few clouds'},
#  {'City': 'deputatskiy',
#   'Country': 'RU',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 238.5,
#   'Humidity': 100,
#   'Cloudiness': 34,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 276.24,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.26,
#   'Current Description': 'light rain'},
#  {'City': 'adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 292.94,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 4.71,
#   'Current Description': 'clear sky'},
#  {'City': 'nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 295.14,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 3.09,
#   'Current Description': 'clear sky'},
#  {'City': 'potiskum',
#   'Country': 'NG',
#   'Lat': 11.7091,
#   'Lng': 11.0694,
#   'Max Temp': 295.27,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 5.04,
#   'Current Description': 'clear sky'},
#  {'City': 'rawson',
#   'Country': 'AR',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 288.28,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 8.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'rindal',
#   'Country': 'NO',
#   'Lat': 63.0565,
#   'Lng': 9.2124,
#   'Max Temp': 275.2,
#   'Humidity': 44,
#   'Cloudiness': 2,
#   'Wind Speed': 3.66,
#   'Current Description': 'clear sky'},
#  {'City': 'boa vista',
#   'Country': 'BR',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 298.14,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Current Description': 'clear sky'},
#  {'City': 'codrington',
#   'Country': 'AU',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 287.32,
#   'Humidity': 69,
#   'Cloudiness': 17,
#   'Wind Speed': 5.14,
#   'Current Description': 'few clouds'},
#  {'City': 'los llanos de aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 293.22,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 5.36,
#   'Current Description': 'clear sky'},
#  {'City': 'chitral',
#   'Country': 'PK',
#   'Lat': 35.8462,
#   'Lng': 71.7858,
#   'Max Temp': 281.19,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 4.81,
#   'Current Description': 'clear sky'},
#  {'City': 'marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 295.76,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Current Description': 'light rain'},
#  {'City': 'mamallapuram',
#   'Country': 'IN',
#   'Lat': 12.6264,
#   'Lng': 80.1722,
#   'Max Temp': 303.18,
#   'Humidity': 58,
#   'Cloudiness': 4,
#   'Wind Speed': 6.31,
#   'Current Description': 'clear sky'},
#  {'City': 'mount gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 288.42,
#   'Humidity': 62,
#   'Cloudiness': 65,
#   'Wind Speed': 4.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'livingston',
#   'Country': 'GB',
#   'Lat': 55.9029,
#   'Lng': -3.5226,
#   'Max Temp': 281.42,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Current Description': 'light intensity drizzle rain'},
#  {'City': 'samarai',
#   'Country': 'PG',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 302.77,
#   'Humidity': 75,
#   'Cloudiness': 49,
#   'Wind Speed': 6.73,
#   'Current Description': 'scattered clouds'},
#  {'City': 'patacamaya',
#   'Country': 'BO',
#   'Lat': -17.2333,
#   'Lng': -67.9167,
#   'Max Temp': 278.35,
#   'Humidity': 76,
#   'Cloudiness': 6,
#   'Wind Speed': 3.1,
#   'Current Description': 'clear sky'},
#  {'City': 'cabo san lucas',
#   'Country': 'MX',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 296.77,
#   'Humidity': 70,
#   'Cloudiness': 85,
#   'Wind Speed': 0.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'thinadhoo',
#   'Country': 'MV',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 300.7,
#   'Humidity': 70,
#   'Cloudiness': 93,
#   'Wind Speed': 5.9,
#   'Current Description': 'overcast clouds'},
#  {'City': 'pokhara',
#   'Country': 'NP',
#   'Lat': 28.2333,
#   'Lng': 83.9833,
#   'Max Temp': 293.87,
#   'Humidity': 57,
#   'Cloudiness': 27,
#   'Wind Speed': 2.33,
#   'Current Description': 'scattered clouds'},
#  {'City': 'kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 300.26,
#   'Humidity': 83,
#   'Cloudiness': 52,
#   'Wind Speed': 1.3,
#   'Current Description': 'moderate rain'},
#  {'City': 'batalha',
#   'Country': 'BR',
#   'Lat': -9.6778,
#   'Lng': -37.1247,
#   'Max Temp': 294.98,
#   'Humidity': 92,
#   'Cloudiness': 18,
#   'Wind Speed': 2.34,
#   'Current Description': 'few clouds'},
#  {'City': 'troitsko-pechorsk',
#   'Country': 'RU',
#   'Lat': 62.7084,
#   'Lng': 56.1964,
#   'Max Temp': 250.45,
#   'Humidity': 96,
#   'Cloudiness': 7,
#   'Wind Speed': 1.22,
#   'Current Description': 'clear sky'},
#  {'City': 'vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 281.88,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 18.75,
#   'Current Description': 'moderate rain'},
#  {'City': 'ostersund',
#   'Country': 'SE',
#   'Lat': 63.1792,
#   'Lng': 14.6357,
#   'Max Temp': 267.4,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Current Description': 'fog'},
#  {'City': 'nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 274.15,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.43,
#   'Current Description': 'light snow'},
#  {'City': 'sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 301.09,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 3.48,
#   'Current Description': 'clear sky'},
#  {'City': 'asau',
#   'Country': 'RO',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 276.66,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 0.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'sabang',
#   'Country': 'ID',
#   'Lat': 5.8933,
#   'Lng': 95.3214,
#   'Max Temp': 300.89,
#   'Humidity': 76,
#   'Cloudiness': 64,
#   'Wind Speed': 10.7,
#   'Current Description': 'light rain'},
#  {'City': 'basco',
#   'Country': 'PH',
#   'Lat': 20.4487,
#   'Lng': 121.9702,
#   'Max Temp': 300.5,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'ullapool',
#   'Country': 'GB',
#   'Lat': 57.8987,
#   'Lng': -5.1604,
#   'Max Temp': 281.68,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.45,
#   'Current Description': 'overcast clouds'},
#  {'City': 'clyde river',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 254.28,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Current Description': 'light snow'},
#  {'City': 'ugoofaaru',
#   'Country': 'MV',
#   'Lat': 5.6667,
#   'Lng': 73,
#   'Max Temp': 300.76,
#   'Humidity': 75,
#   'Cloudiness': 43,
#   'Wind Speed': 4.37,
#   'Current Description': 'scattered clouds'},
#  {'City': 'san quintin',
#   'Country': 'MX',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 288.6,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 2.21,
#   'Current Description': 'clear sky'},
#  {'City': 'emerald',
#   'Country': 'AU',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 303,
#   'Humidity': 18,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'zhigansk',
#   'Country': 'RU',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 249.85,
# ...
#  {'City': 'haines junction',
#   'Country': 'CA',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 263.12,
#   'Humidity': 85,
#   'Cloudiness': 97,
#   'Wind Speed': 0.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'goundam',
#   'Country': 'ML',
#   'Lat': 16.4145,
#   'Lng': -3.6708,
#   'Max Temp': 294.64,
#   'Humidity': 19,
#   'Cloudiness': 4,
#   'Wind Speed': 4.17,
#   'Current Description': 'clear sky'},
#  {'City': 'si satchanalai',
#   'Country': 'TH',
#   'Lat': 17.5169,
#   'Lng': 99.7598,
#   'Max Temp': 306.03,
#   'Humidity': 62,
#   'Cloudiness': 34,
#   'Wind Speed': 1.62,
#   'Current Description': 'scattered clouds'},
#  {'City': 'barra do garcas',
#   'Country': 'BR',
#   'Lat': -15.89,
#   'Lng': -52.2567,
#   'Max Temp': 294.79,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 1.26,
#   'Current Description': 'clear sky'},
#  {'City': 'lata',
#   'Country': 'PT',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 289.3,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'itarema',
#   'Country': 'BR',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 298.52,
#   'Humidity': 76,
#   'Cloudiness': 67,
#   'Wind Speed': 5.38,
#   'Current Description': 'broken clouds'},
#  {'City': 'gibsons',
#   'Country': 'CA',
#   'Lat': 49.3997,
#   'Lng': -123.5027,
#   'Max Temp': 280.4,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 2.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'charters towers',
#   'Country': 'AU',
#   'Lat': -20.1,
#   'Lng': 146.2667,
#   'Max Temp': 306.71,
#   'Humidity': 16,
#   'Cloudiness': 100,
#   'Wind Speed': 4.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'diamantino',
#   'Country': 'BR',
#   'Lat': -14.4086,
#   'Lng': -56.4461,
#   'Max Temp': 294.38,
#   'Humidity': 50,
#   'Cloudiness': 6,
#   'Wind Speed': 1.36,
#   'Current Description': 'clear sky'},
#  {'City': 'pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 254.01,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.37,
#   'Current Description': 'overcast clouds'},
#  {'City': 'rabaul',
#   'Country': 'PG',
#   'Lat': -4.1967,
#   'Lng': 152.1721,
#   'Max Temp': 302.4,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'inuvik',
#   'Country': 'CA',
#   'Lat': 68.3499,
#   'Lng': -133.7218,
#   'Max Temp': 268.63,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Current Description': 'few clouds'},
#  {'City': 'campbell river',
#   'Country': 'CA',
#   'Lat': 50.0163,
#   'Lng': -125.2446,
#   'Max Temp': 276.73,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'gawler',
#   'Country': 'AU',
#   'Lat': -34.6,
#   'Lng': 138.7333,
#   'Max Temp': 297.09,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 3.72,
#   'Current Description': 'clear sky'},
#  {'City': 'rock springs',
#   'Country': 'US',
#   'Lat': 41.5875,
#   'Lng': -109.2029,
#   'Max Temp': 269.29,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Current Description': 'clear sky'},
#  {'City': 'brownwood',
#   'Country': 'US',
#   'Lat': 31.7093,
#   'Lng': -98.9912,
#   'Max Temp': 280.77,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'kayunga',
#   'Country': 'UG',
#   'Lat': 0.7025,
#   'Lng': 32.8886,
#   'Max Temp': 297.01,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 0.05,
#   'Current Description': 'broken clouds'},
#  {'City': 'batu',
#   'Country': 'ID',
#   'Lat': -7.87,
#   'Lng': 112.5283,
#   'Max Temp': 299.41,
#   'Humidity': 69,
#   'Cloudiness': 43,
#   'Wind Speed': 0.86,
#   'Current Description': 'scattered clouds'},
#  {'City': 'neryungri',
#   'Country': 'RU',
#   'Lat': 56.6709,
#   'Lng': 124.6491,
#   'Max Temp': 261.17,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'gainesville',
#   'Country': 'US',
#   'Lat': 29.6516,
#   'Lng': -82.3248,
#   'Max Temp': 284.27,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Current Description': 'clear sky'},
#  {'City': 'dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 286.37,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Current Description': 'light rain'},
#  {'City': 'slyudyanka',
#   'Country': 'RU',
#   'Lat': 51.6594,
#   'Lng': 103.7061,
#   'Max Temp': 277.13,
#   'Humidity': 57,
#   'Cloudiness': 30,
#   'Wind Speed': 0.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'lazarevac',
#   'Country': 'RS',
#   'Lat': 44.3853,
#   'Lng': 20.2557,
#   'Max Temp': 282.06,
#   'Humidity': 86,
#   'Cloudiness': 63,
#   'Wind Speed': 2.58,
#   'Current Description': 'broken clouds'},
#  {'City': 'meadow lake',
#   'Country': 'US',
#   'Lat': 34.8014,
#   'Lng': -106.5436,
#   'Max Temp': 273.21,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 1.34,
#   'Current Description': 'clear sky'},
#  {'City': 'sungaipenuh',
#   'Country': 'ID',
#   'Lat': -2.0833,
#   'Lng': 101.3833,
#   'Max Temp': 296.4,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Current Description': 'overcast clouds'},
#  {'City': 'kieta',
#   'Country': 'PG',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 301.14,
#   'Humidity': 70,
#   'Cloudiness': 96,
#   'Wind Speed': 1.72,
#   'Current Description': 'overcast clouds'},
#  {'City': 'hay river',
#   'Country': 'CA',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 259.14,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Current Description': 'scattered clouds'},
#  {'City': 'orje',
#   'Country': 'NO',
#   'Lat': 59.4802,
#   'Lng': 11.6602,
#   'Max Temp': 273.91,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 4.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'megion',
#   'Country': 'RU',
#   'Lat': 61.0296,
#   'Lng': 76.1136,
#   'Max Temp': 251.49,
#   'Humidity': 87,
#   'Cloudiness': 21,
#   'Wind Speed': 3.06,
#   'Current Description': 'few clouds'},
#  {'City': 'arisvi',
#   'Country': 'GR',
#   'Lat': 41.0667,
#   'Lng': 25.5833,
#   'Max Temp': 289.94,
#   'Humidity': 93,
#   'Cloudiness': 74,
#   'Wind Speed': 4.24,
#   'Current Description': 'broken clouds'},
#  {'City': 'poum',
#   'Country': 'NC',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 300.09,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'semporna',
#   'Country': 'MY',
#   'Lat': 4.4818,
#   'Lng': 118.6112,
#   'Max Temp': 303,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 1.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'abnub',
#   'Country': 'EG',
#   'Lat': 27.2696,
#   'Lng': 31.1511,
#   'Max Temp': 288.27,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'altona',
#   'Country': 'DE',
#   'Lat': 53.55,
#   'Lng': 9.9333,
#   'Max Temp': 277.12,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'zaraza',
#   'Country': 'VE',
#   'Lat': 9.3503,
#   'Lng': -65.3245,
#   'Max Temp': 294.99,
#   'Humidity': 96,
#   'Cloudiness': 95,
#   'Wind Speed': 1.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'houston',
#   'Country': 'US',
#   'Lat': 29.7633,
#   'Lng': -95.3633,
#   'Max Temp': 282.57,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Current Description': 'broken clouds'},
#  {'City': 'san lorenzo',
#   'Country': 'PY',
#   'Lat': -25.3333,
#   'Lng': -57.5333,
#   'Max Temp': 289.67,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'yulara',
#   'Country': 'AU',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 301,
#   'Humidity': 40,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'rancho palos verdes',
#   'Country': 'US',
#   'Lat': 33.7445,
#   'Lng': -118.387,
#   'Max Temp': 291.7,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Current Description': 'clear sky'},
#  {'City': 'ustka',
#   'Country': 'PL',
#   'Lat': 54.5805,
#   'Lng': 16.8619,
#   'Max Temp': 274.62,
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 7.39,
#   'Current Description': 'clear sky'},
#  {'City': 'carnot',
#   'Country': 'CF',
#   'Lat': 4.9409,
#   'Lng': 15.8665,
#   'Max Temp': 298.69,
#   'Humidity': 51,
#   'Cloudiness': 14,
#   'Wind Speed': 0.88,
#   'Current Description': 'few clouds'},
#  {'City': 'nantucket',
#   'Country': 'US',
#   'Lat': 41.2835,
#   'Lng': -70.0995,
#   'Max Temp': 281.21,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Current Description': 'scattered clouds'},
#  {'City': 'nanakuli',
#   'Country': 'US',
#   'Lat': 21.3906,
#   'Lng': -158.1547,
#   'Max Temp': 298.12,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Current Description': 'clear sky'},
#  {'City': 'innisfail',
#   'Country': 'AU',
#   'Lat': -17.5333,
#   'Lng': 146.0333,
#   'Max Temp': 301.76,
#   'Humidity': 47,
#   'Cloudiness': 6,
#   'Wind Speed': 2.83,
#   'Current Description': 'clear sky'},
#  {'City': 'victor harbor',
#   'Country': 'AU',
#   'Lat': -35.5667,
#   'Lng': 138.6167,
#   'Max Temp': 290.37,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.6,
#   'Current Description': 'clear sky'},
#  {'City': 'salmas',
#   'Country': 'IR',
#   'Lat': 38.1973,
#   'Lng': 44.7653,
#   'Max Temp': 282.48,
#   'Humidity': 55,
#   'Cloudiness': 17,
#   'Wind Speed': 1.31,
#   'Current Description': 'few clouds'},
#  {'City': 'waipawa',
#   'Country': 'NZ',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 286.69,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Current Description': 'light rain'},
#  {'City': 'coos bay',
#   'Country': 'US',
#   'Lat': 43.3665,
#   'Lng': -124.2179,
#   'Max Temp': 280.33,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Current Description': 'clear sky'},
#  {'City': 'nizwa',
#   'Country': 'OM',
#   'Lat': 22.9333,
#   'Lng': 57.5333,
#   'Max Temp': 301.92,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 2.71,
#   'Current Description': 'clear sky'},
#  {'City': 'nola',
#   'Country': 'IT',
#   'Lat': 40.922,
#   'Lng': 14.5329,
#   'Max Temp': 290.33,
#   'Humidity': 93,
#   'Cloudiness': 73,
#   'Wind Speed': 1.4,
#   'Current Description': 'broken clouds'},
#  {'City': 'besikduzu',
#   'Country': 'TR',
#   'Lat': 41.052,
#   'Lng': 39.2284,
#   'Max Temp': 290.09,
#   'Humidity': 53,
#   'Cloudiness': 10,
#   'Wind Speed': 1.39,
#   'Current Description': 'clear sky'},
#  {'City': 'pori',
#   'Country': 'FI',
#   'Lat': 61.4833,
#   'Lng': 21.7833,
#   'Max Temp': 271.19,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'tecoanapa',
#   'Country': 'MX',
#   'Lat': 16.5167,
#   'Lng': -98.75,
#   'Max Temp': 297.64,
#   'Humidity': 83,
#   'Cloudiness': 97,
#   'Wind Speed': 2.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'dali',
#   'Country': 'CN',
#   'Lat': 25.7,
#   'Lng': 100.1833,
#   'Max Temp': 291.25,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 3.63,
#   'Current Description': 'clear sky'},
#  {'City': 'beruwala',
#   'Country': 'LK',
#   'Lat': 6.4788,
#   'Lng': 79.9828,
#   'Max Temp': 302.89,
#   'Humidity': 58,
#   'Cloudiness': 4,
#   'Wind Speed': 5.82,
#   'Current Description': 'clear sky'},
#  {'City': 'erenhot',
#   'Country': 'CN',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 279.55,
#   'Humidity': 20,
#   'Cloudiness': 100,
#   'Wind Speed': 3.95,
#   'Current Description': 'overcast clouds'},
#  {'City': 'tuy hoa',
#   'Country': 'VN',
#   'Lat': 13.0833,
#   'Lng': 109.3,
#   'Max Temp': 300.52,
#   'Humidity': 83,
#   'Cloudiness': 81,
#   'Wind Speed': 4.13,
#   'Current Description': 'broken clouds'},
#  {'City': 'dumas',
#   'Country': 'US',
#   'Lat': 35.8656,
#   'Lng': -101.9732,
#   'Max Temp': 271.27,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Current Description': 'clear sky'},
#  {'City': 'praia da vitoria',
#   'Country': 'PT',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 289.29,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 8.81,
#   'Current Description': 'scattered clouds'},
#  {'City': 'camacupa',
#   'Country': 'AO',
#   'Lat': -12.0167,
#   'Lng': 17.4833,
#   'Max Temp': 294.56,
#   'Humidity': 65,
#   'Cloudiness': 92,
#   'Wind Speed': 1.13,
#   'Current Description': 'overcast clouds'},
#  {'City': 'ebeltoft',
#   'Country': 'DK',
#   'Lat': 56.1944,
#   'Lng': 10.6821,
#   'Max Temp': 280.16,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 11.32,
#   'Current Description': 'broken clouds'},
#  {'City': 'babu',
#   'Country': 'CN',
#   'Lat': 24.4167,
#   'Lng': 111.5167,
#   'Max Temp': 294.81,
#   'Humidity': 82,
#   'Cloudiness': 78,
#   'Wind Speed': 1.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'alora',
#   'Country': 'ES',
#   'Lat': 36.8236,
#   'Lng': -4.7058,
#   'Max Temp': 291.75,
#   'Humidity': 86,
#   'Cloudiness': 44,
#   'Wind Speed': 1.89,
#   'Current Description': 'scattered clouds'},
#  {'City': 'miandrivazo',
#   'Country': 'MG',
#   'Lat': -19.5167,
#   'Lng': 45.4667,
#   'Max Temp': 302.9,
#   'Humidity': 56,
#   'Cloudiness': 30,
#   'Wind Speed': 0.77,
#   'Current Description': 'scattered clouds'},
#  {'City': 'eureka',
#   'Country': 'US',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 278.81,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 1.51,
#   'Current Description': 'overcast clouds'},
#  {'City': 'san buenaventura',
#   'Country': 'MX',
#   'Lat': 27.0833,
#   'Lng': -101.5333,
#   'Max Temp': 282.3,
#   'Humidity': 62,
#   'Cloudiness': 99,
#   'Wind Speed': 1.7,
#   'Current Description': 'overcast clouds'},
#  {'City': 'kavaratti',
#   'Country': 'IN',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 300.92,
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind Speed': 1.46,
#   'Current Description': 'clear sky'},
#  {'City': 'broome',
#   'Country': 'US',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 274.92,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'burnie',
#   'Country': 'AU',
#   'Lat': -41.0667,
#   'Lng': 145.9167,
#   'Max Temp': 288.12,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 3.55,
#   'Current Description': 'few clouds'},
#  {'City': 'general roca',
#   'Country': 'AR',
#   'Lat': -39.0333,
#   'Lng': -67.5833,
#   'Max Temp': 291.27,
#   'Humidity': 51,
#   'Cloudiness': 18,
#   'Wind Speed': 6.21,
#   'Current Description': 'few clouds'},
#  {'City': 'praya',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 296.45,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Current Description': 'few clouds'},
#  {'City': 'ndola',
#   'Country': 'ZM',
#   'Lat': -12.9587,
#   'Lng': 28.6366,
#   'Max Temp': 297.64,
#   'Humidity': 56,
#   'Cloudiness': 30,
#   'Wind Speed': 2.67,
#   'Current Description': 'scattered clouds'},
#  {'City': 'kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 292.2,
#   'Humidity': 25,
#   'Cloudiness': 4,
#   'Wind Speed': 3.84,
#   'Current Description': 'clear sky'},
#  {'City': 'kupang',
#   'Country': 'ID',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 305.47,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Current Description': 'broken clouds'},
#  {'City': 'yinchuan',
#   'Country': 'CN',
#   'Lat': 38.4681,
#   'Lng': 106.2731,
#   'Max Temp': 285.58,
#   'Humidity': 40,
#   'Cloudiness': 100,
#   'Wind Speed': 1.11,
#   'Current Description': 'overcast clouds'},
#  {'City': 'sakakah',
#   'Country': 'SA',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 289.91,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 3.15,
#   'Current Description': 'light rain'},
#  {'City': 'santo antonio do ica',
#   'Country': 'BR',
#   'Lat': -3.1022,
#   'Lng': -67.9397,
#   'Max Temp': 295.36,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'semibratovo',
#   'Country': 'RU',
#   'Lat': 57.3046,
#   'Lng': 39.5369,
#   'Max Temp': 269.07,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 4.01,
#   'Current Description': 'overcast clouds'},
#  {'City': 'vilyuysk',
#   'Country': 'RU',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': 254.83,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Current Description': 'overcast clouds'}]

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           busselton      AU -33.6500  115.3333    290.30        55
# 1             mataura      NZ -46.1927  168.8643    287.86        89
# 2  concepcion del oro      MX  24.6333 -101.4167    283.36        70
# 3               lagoa      PT  39.0500  -27.9833    288.65        66
# 4           nishihara      JP  26.1842  127.7558    298.96        69
# 5            thompson      CA  55.7435  -97.8558    263.24        79
# 6             mayumba      GA  -3.4320   10.6554    296.89        90
# 7               nadym      RU  65.5333   72.5167    255.70        84
# 8        saint-pierre      RE -21.3393   55.4781    298.97        50
# 9         port alfred      ZA -33.5906   26.8910    292.69        79
#
#    Cloudiness  Wind Speed Current Description
# 0          79        9.02       broken clouds
# 1          97        1.55     overcast clouds
# 2          17        2.90          few clouds
# 3         100        9.95     overcast clouds
# 4          75        6.69          light rain
# 5         100        6.69          light snow
# 6         100        4.09       moderate rain
# 7          98        5.87     overcast clouds
# 8           0        4.12           clear sky
# 9          88        2.24     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_list]

# Display sample data
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           busselton      AU -33.6500  115.3333    290.30        55
# 1             mataura      NZ -46.1927  168.8643    287.86        89
# 2  concepcion del oro      MX  24.6333 -101.4167    283.36        70
# 3               lagoa      PT  39.0500  -27.9833    288.65        66
# 4           nishihara      JP  26.1842  127.7558    298.96        69
# 5            thompson      CA  55.7435  -97.8558    263.24        79
# 6             mayumba      GA  -3.4320   10.6554    296.89        90
# 7               nadym      RU  65.5333   72.5167    255.70        84
# 8        saint-pierre      RE -21.3393   55.4781    298.97        50
# 9         port alfred      ZA -33.5906   26.8910    292.69        79
#
#    Cloudiness  Wind Speed Current Description
# 0          79        9.02       broken clouds
# 1          97        1.55     overcast clouds
# 2          17        2.90          few clouds
# 3         100        9.95     overcast clouds
# 4          75        6.69          light rain
# 5         100        6.69          light snow
# 6         100        4.09       moderate rain
# 7          98        5.87     overcast clouds
# 8           0        4.12           clear sky
# 9          88        2.24     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
OutputFileName = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(OutputFileName)
